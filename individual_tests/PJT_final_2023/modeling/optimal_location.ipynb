# %% [markdown]
# ### 1. 각 군집의 centroid 부터 거리 계산 (주성분 활용)_최종

# %%
import pandas as pd
import numpy as np

pca_result = pd.read_csv('./data/minmax_scaling_PCA_label.csv', index_col=0)
subway_data = pd.read_csv('./data/서울지하철_공공데이터_호선별_역별_승하차인원_일평균_행정동포함.csv')
subway_data['호선+역명'] = subway_data['호선'] + '_' + subway_data['역명'] + " "

# kmeans centroid numpy array 불러오기
centroids = np.load('./data/kmeans_centroid.npy')

# %%
# 클러스터 레이블 별로 데이터프레임 나누기
pca_cluster_0 = pca_result[pca_result['cluster'] == 0]
pca_cluster_1 = pca_result[pca_result['cluster'] == 1]
pca_cluster_2 = pca_result[pca_result['cluster'] == 2]
pca_cluster_3 = pca_result[pca_result['cluster'] == 3]

# %%
# 거리 계산 함수 생성
def calculate_distance(a, b):
    distance = 0
    for i in range(len(a)):
        distance += (a[i] - b[i]) ** 2
    return distance ** 0.5

# %%
# 오류 메시지 비활성화
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
# 각 cluster centroid로부터 떨어진 거리 계산 -> 'distance' 컬럼
pca_clusters = [pca_cluster_0, pca_cluster_1, pca_cluster_2, pca_cluster_3]

for i, pca_cluster in enumerate(pca_clusters):
    tmp = pca_cluster.drop('cluster', axis=1)
    distances = [calculate_distance(centroids[i], point) for point in tmp.values]
    pca_cluster.loc[:,'distance'] = distances

# %% [markdown]
# 클러스터별 최단 거리 5위 뽑아보기

# %%
# 클러스터별 최단 거리 상위 5개 행정동 추출
top_5 = pd.concat([
    pca_cluster_0.sort_values('distance').head(5),
    pca_cluster_1.sort_values('distance').head(5),
    pca_cluster_2.sort_values('distance').head(5),
    pca_cluster_3.sort_values('distance').head(5),
])

# %%
# 추출된 행정동에 위치한 지하철역 mapping
area_w_subway = subway_data.groupby('행정동')['호선+역명'].sum().to_frame()

for i in top_5.index:
    for j in area_w_subway.index:
        if i == j:
            top_5.loc[i, 'subway'] = area_w_subway.loc[j, '호선+역명']

top_5['subway'].fillna("", inplace=True)
top_5['subway'] = top_5['subway'].map(lambda x: ','.join(x.split()))
top_5
# Out:
#               0         1         2         3         4         5  cluster  \
# 행정동명
# 송파2동   0.079815 -0.244630  0.027826  0.015311 -0.039013 -0.010445        0
# 남가좌1동  0.088593 -0.312289  0.017162 -0.167120  0.047328  0.041055        0
# 하계2동   0.164587 -0.306063 -0.004596 -0.099306 -0.003715 -0.035986        0
# 방이1동  -0.056980 -0.250338  0.119408 -0.080721 -0.087399  0.055004        0
# 방배3동   0.100324 -0.300655  0.057266  0.061770  0.054492  0.053401        0
# 면목4동  -0.075829 -0.078424 -0.163650  0.052472  0.042259  0.000171        1
# 암사1동  -0.065351 -0.064685 -0.098996 -0.018784  0.066846  0.051345        1
# 홍제3동  -0.044947 -0.102270 -0.078139  0.104911  0.052648 -0.021009        1
# 화곡2동  -0.077616 -0.105319 -0.091817 -0.046530 -0.033173  0.018272        1
# 왕십리2동 -0.095186 -0.099579 -0.080063 -0.030630 -0.046733  0.044464        1
# 응암1동   0.340923  0.146296 -0.036382 -0.043997  0.010936 -0.063194        2
# 공항동    0.234698  0.127700  0.074049  0.056836 -0.034086  0.019892        2
# 은천동    0.292253  0.173590 -0.085477  0.054455 -0.064382 -0.050564        2
# 장안2동   0.335295  0.068695 -0.013889 -0.043233  0.007422 -0.085243        2
# 홍은2동   0.241983  0.094071 -0.057664 -0.008708  0.075267 -0.032089        2
# 연남동   -0.279381  0.241751  0.054741 -0.141780 -0.030941  0.037321        3
# 청파동   -0.192223  0.245593  0.034787 -0.019479 -0.086504 -0.016093        3
# 대흥동   -0.293714  0.241550  0.094023 -0.045394 -0.137476 -0.093218        3
# 합정동   -0.215536  0.204466  0.044690 -0.140127 -0.039214  0.076269        3
# 혜화동   -0.219628  0.222779  0.197047 -0.057721 -0.074808 -0.047043        3
#
#        distance         subway
# 행정동명
# 송파2동   0.143294
# 남가좌1동  0.158830       경의중앙선_가좌
# 하계2동   0.163167         7호선_하계
# 방이1동   0.168104         5호선_방이
# 방배3동   0.173730         2호선_방배
# 면목4동   0.089658        7호선_용마산
# 암사1동   0.093978         8호선_암사
# 홍제3동   0.110024         3호선_홍제
# 화곡2동   0.112856
# 왕십리2동  0.113090       2호선_상왕십리
# 응암1동   0.121328
# 공항동    0.123388  5호선_마곡,5호선_송정
# 은천동    0.133971         2호선_봉천
# 장안2동   0.138741
# 홍은2동   0.156357
# 연남동    0.110855
# 청파동    0.114260
# 대흥동    0.146279  2호선_이대,6호선_대흥
# 합정동    0.157352         6호선_합정
# 혜화동    0.157554

# %%
top_5.to_csv('./data/optimal_location_w_subway_station.csv')

# %% [markdown]
# - 전체 클러스터

# %%
cluster = pd.concat([
    pca_cluster_0.sort_values('distance'),
    pca_cluster_1.sort_values('distance'),
    pca_cluster_2.sort_values('distance'),
    pca_cluster_3.sort_values('distance'),
]) #전체 클러스터

# %%
# 추출된 행정동에 위치한 지하철역 mapping
area_w_subway = subway_data.groupby('행정동')['호선+역명'].sum().to_frame()

for i in cluster.index:
    for j in area_w_subway.index:
        if i == j:
            cluster.loc[i, 'subway'] = area_w_subway.loc[j, '호선+역명']

cluster['subway'].fillna("", inplace=True)
cluster['subway'] = cluster['subway'].map(lambda x: ','.join(x.split()))
cluster
# Out:
#                     0         1         2         3         4         5  \
# 행정동명
# 송파2동         0.079815 -0.244630  0.027826  0.015311 -0.039013 -0.010445
# 남가좌1동        0.088593 -0.312289  0.017162 -0.167120  0.047328  0.041055
# 하계2동         0.164587 -0.306063 -0.004596 -0.099306 -0.003715 -0.035986
# 방이1동        -0.056980 -0.250338  0.119408 -0.080721 -0.087399  0.055004
# 방배3동         0.100324 -0.300655  0.057266  0.061770  0.054492  0.053401
# ...               ...       ...       ...       ...       ...       ...
# 둔촌1동        -0.621720 -0.141444  0.188045 -0.126260 -0.362875  0.062102
# 필동          -0.660355 -0.048411  0.392070  0.419604 -0.405873 -0.258607
# 명동          -0.523548  0.380905  0.775273  0.175097  0.416959  0.214580
# 서교동          0.031945  0.882373  0.650519 -0.093045  0.266645 -0.126773
# 종로1.2.3.4가동 -0.549133  0.754336  1.115468  0.628705  0.727712 -0.291113
#
#              cluster  distance                                       subway
# 행정동명
# 송파2동               0  0.143294
# 남가좌1동              0  0.158830                                     경의중앙선_가좌
# 하계2동               0  0.163167                                       7호선_하계
# 방이1동               0  0.168104                                       5호선_방이
# 방배3동               0  0.173730                                       2호선_방배
# ...              ...       ...                                          ...
# 둔촌1동               3  0.663973                                     9호선_둔촌오륜
# 필동                 3  0.892370                              3호선_충무로,4호선_충무로
# 명동                 3  0.933855                             2호선_을지로입구,4호선_명동
# 서교동                3  0.937082  2호선_합정,2호선_홍대입구,6호선_망원,경의중앙선_홍대입구,공항철도_홍대입구
# 종로1.2.3.4가동        3  1.585267     1호선_종각,1호선_종로3가,3호선_안국,3호선_종로3가,5호선_종로3가
#
# [426 rows x 9 columns]

# %% [markdown]
# ### 컬럼별 서울시 전체 평균, 클러스터별 평균 구하기

# %% [markdown]
# - original data

# %%
result = pd.DataFrame([original_df.mean(), cluster_0.mean(), cluster_1.mean(), cluster_2.mean(), cluster_3.mean()], index = ['서울시 전체', 'cluster0', 'cluster1', 'clutser2', 'cluster3'])
result
# Out:
#              미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체    25.476817  4.232394     0.262911      77.733513  3.326291
# cluster0  20.972684  4.092105     0.263158     127.965954  1.921053
# cluster1  19.699113  3.062147     0.118644      59.416775  3.604520
# clutser2  22.532050  7.310000     0.400000      47.197226  3.820000
# cluster3  48.208932  3.000000     0.424658     111.679069  3.438356
#
#           제로웨이스트 가게수   승하차인원_버스_지하철        카페수  유치원_초등학교           인구수  \
# 서울시 전체      0.636150  310647.906103  51.877934  0.000095  40772.171362
# cluster0    0.328947  247284.092105  39.710526  0.000119  34983.263158
# cluster1    0.259887  207714.299435  32.288136  0.000093  33996.446328
# clutser2    0.960000  426431.140000  67.250000  0.000084  63910.970000
# cluster3    1.424658  467587.287671  90.986301  0.000089  31530.808219
#
#              총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체    0.074794  0.297185  0.260617  0.435510
# cluster0  0.115728  0.234621  0.229287  0.256747
# cluster1  0.064191  0.280858  0.292038  0.439798
# clutser2  0.083270  0.296587  0.255910  0.406062
# cluster3  0.046276  0.402727  0.223494  0.651561

# %%
pd.DataFrame([original_df.mean(), cluster_0.mean()], index = ['서울시 전체', 'cluster0'])
# Out:
#              미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체    25.476817  4.232394     0.262911      77.733513  3.326291
# cluster0  20.972684  4.092105     0.263158     127.965954  1.921053
#
#           제로웨이스트 가게수   승하차인원_버스_지하철        카페수  유치원_초등학교           인구수  \
# 서울시 전체      0.636150  310647.906103  51.877934  0.000095  40772.171362
# cluster0    0.328947  247284.092105  39.710526  0.000119  34983.263158
#
#              총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체    0.074794  0.297185  0.260617  0.435510
# cluster0  0.115728  0.234621  0.229287  0.256747

# %%
pd.DataFrame([original_df.mean(), cluster_1.mean()], index = ['서울시 전체', 'cluster1'])
# Out:
#              미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체    25.476817  4.232394     0.262911      77.733513  3.326291
# cluster1  19.699113  3.062147     0.118644      59.416775  3.604520
#
#           제로웨이스트 가게수   승하차인원_버스_지하철        카페수  유치원_초등학교           인구수  \
# 서울시 전체      0.636150  310647.906103  51.877934  0.000095  40772.171362
# cluster1    0.259887  207714.299435  32.288136  0.000093  33996.446328
#
#              총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체    0.074794  0.297185  0.260617  0.435510
# cluster1  0.064191  0.280858  0.292038  0.439798

# %%
pd.DataFrame([original_df.mean(), cluster_2.mean()], index = ['서울시 전체', 'cluster2'])
# Out:
#              미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체    25.476817  4.232394     0.262911      77.733513  3.326291
# cluster2  22.532050  7.310000     0.400000      47.197226  3.820000
#
#           제로웨이스트 가게수   승하차인원_버스_지하철        카페수  유치원_초등학교           인구수  \
# 서울시 전체       0.63615  310647.906103  51.877934  0.000095  40772.171362
# cluster2     0.96000  426431.140000  67.250000  0.000084  63910.970000
#
#              총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체    0.074794  0.297185  0.260617  0.435510
# cluster2  0.083270  0.296587  0.255910  0.406062

# %%
pd.DataFrame([original_df.mean(), cluster_3.mean()], index = ['서울시 전체', 'cluster3'])
# Out:
#              미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체    25.476817  4.232394     0.262911      77.733513  3.326291
# cluster3  48.208932  3.000000     0.424658     111.679069  3.438356
#
#           제로웨이스트 가게수   승하차인원_버스_지하철        카페수  유치원_초등학교           인구수  \
# 서울시 전체      0.636150  310647.906103  51.877934  0.000095  40772.171362
# cluster3    1.424658  467587.287671  90.986301  0.000089  31530.808219
#
#              총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체    0.074794  0.297185  0.260617  0.435510
# cluster3  0.046276  0.402727  0.223494  0.651561

# %% [markdown]
# - scaled data

# %%
# minmax scaled data 불러오기
scaled_df = pd.read_csv('./data/minmax_scaling.csv', index_col=0)
if scaled_df.index.equals(pca_result.index):
    tmp = scaled_df.copy()
    tmp['cluster'] = pca_result['cluster']
tmp.head(2)
# Out:
#         미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  제로웨이스트 가게수  \
# 행정동명
# 가락1동  0.014204  0.076923          0.0       0.025989  0.116279         0.0
# 가락2동  0.014204  0.346154          0.0       0.035016  0.034884         0.0
#
#       승하차인원_버스_지하철       카페수  유치원_초등학교       인구수     총_10대  총_20_30대  \
# 행정동명
# 가락1동      0.085682  0.105911  0.125300  0.639775  0.426207  0.408414
# 가락2동      0.088504  0.182266  0.220257  0.745585  0.466991  0.415310
#
#        총_60대이상      1인세대  cluster
# 행정동명
# 가락1동  0.457904  0.112284        0
# 가락2동  0.489702  0.269226        2

# %%
# 클러스터별 따로 데이터프레임 만들기
scaled_cluster_0 = tmp[tmp['cluster'] == 0].drop('cluster', axis=1)
scaled_cluster_1 = tmp[tmp['cluster'] == 1].drop('cluster', axis=1)
scaled_cluster_2 = tmp[tmp['cluster'] == 2].drop('cluster', axis=1)
scaled_cluster_3 = tmp[tmp['cluster'] == 3].drop('cluster', axis=1)

# %%
top_5.index[:5]
# Out:
# Index(['송파2동', '남가좌1동', '하계2동', '방이1동', '방배3동'], dtype='object', name='행정동명')

# %%
scaled_result = pd.DataFrame([scaled_df.mean(), scaled_cluster_0.mean(), scaled_cluster_1.mean(), scaled_cluster_2.mean(), scaled_cluster_3.mean()], index = ['서울시 전체', 'scaled_cluster0', 'scaled_cluster1', 'scaled_clutser2', 'scaled_cluster3'])
scaled_result
# Out:
#                    미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체           0.041083  0.162784     0.023901       0.077117  0.038678
# scaled_cluster0  0.027505  0.157389     0.023923       0.127592  0.022338
# scaled_cluster1  0.023666  0.117775     0.010786       0.058712  0.041913
# scaled_clutser2  0.032206  0.281154     0.036364       0.046434  0.044419
# scaled_cluster3  0.109606  0.115385     0.038605       0.111226  0.039981
#
#                  제로웨이스트 가게수  승하차인원_버스_지하철       카페수  유치원_초등학교       인구수  \
# 서울시 전체             0.020521      0.152383  0.127778  0.218402  0.440374
# scaled_cluster0    0.010611      0.118819  0.097809  0.273914  0.359629
# scaled_cluster1    0.008383      0.097860  0.079527  0.214019  0.345865
# scaled_clutser2    0.030968      0.213712  0.165640  0.193669  0.763118
# scaled_cluster3    0.045957      0.235512  0.224104  0.205114  0.311474
#
#                     총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체           0.332697  0.445560  0.565364  0.458104
# scaled_cluster0  0.516109  0.351139  0.496944  0.228707
# scaled_cluster1  0.285187  0.420920  0.633986  0.463607
# scaled_clutser2  0.370675  0.444657  0.555086  0.420316
# scaled_cluster3  0.204914  0.604845  0.484293  0.735352

# %%
pd.DataFrame([scaled_df.mean(), 
              scaled_cluster_0.mean(), 
              (scaled_cluster_0.loc[top_5.index[:5], :]).mean()], 
              index = ['서울시 전체', 'scaled_cluster0', 'cluster0_top5'])
# Out:
#                    미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체           0.041083  0.162784     0.023901       0.077117  0.038678
# scaled_cluster0  0.027505  0.157389     0.023923       0.127592  0.022338
# cluster0_top5    0.012883  0.176923     0.000000       0.068459  0.023256
#
#                  제로웨이스트 가게수  승하차인원_버스_지하철       카페수  유치원_초등학교       인구수  \
# 서울시 전체             0.020521      0.152383  0.127778  0.218402  0.440374
# scaled_cluster0    0.010611      0.118819  0.097809  0.273914  0.359629
# cluster0_top5      0.006452      0.087776  0.073399  0.246482  0.368494
#
#                     총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체           0.332697  0.445560  0.565364  0.458104
# scaled_cluster0  0.516109  0.351139  0.496944  0.228707
# cluster0_top5    0.463867  0.376258  0.518357  0.219776

# %%
pd.DataFrame([scaled_df.mean(), 
              scaled_cluster_1.mean(), 
              (scaled_cluster_1.loc[top_5.index[5:10], :]).mean()], 
              index = ['서울시 전체', 'scaled_cluster1', 'cluster1_top5'])
# Out:
#                    미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체           0.041083  0.162784     0.023901       0.077117  0.038678
# scaled_cluster1  0.023666  0.117775     0.010786       0.058712  0.041913
# cluster1_top5    0.006410  0.138462     0.000000       0.030307  0.072093
#
#                  제로웨이스트 가게수  승하차인원_버스_지하철       카페수  유치원_초등학교       인구수  \
# 서울시 전체             0.020521      0.152383  0.127778  0.218402  0.440374
# scaled_cluster1    0.008383      0.097860  0.079527  0.214019  0.345865
# cluster1_top5      0.006452      0.076962  0.063547  0.198799  0.355238
#
#                     총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체           0.332697  0.445560  0.565364  0.458104
# scaled_cluster1  0.285187  0.420920  0.633986  0.463607
# cluster1_top5    0.299799  0.420339  0.605520  0.427940

# %%
pd.DataFrame([
    scaled_df.mean(), 
    scaled_cluster_2.mean(), 
    (scaled_cluster_2.loc[top_5.index[10:15], :]).mean()], 
    index = ['서울시 전체', 'scaled_cluster2', 'cluster2_top5'])
# Out:
#                    미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체           0.041083  0.162784     0.023901       0.077117  0.038678
# scaled_cluster2  0.032206  0.281154     0.036364       0.046434  0.044419
# cluster2_top5    0.059563  0.207692     0.036364       0.036818  0.034884
#
#                  제로웨이스트 가게수  승하차인원_버스_지하철       카페수  유치원_초등학교       인구수  \
# 서울시 전체             0.020521      0.152383  0.127778  0.218402  0.440374
# scaled_cluster2    0.030968      0.213712  0.165640  0.193669  0.763118
# cluster2_top5      0.019355      0.220057  0.126601  0.175607  0.746545
#
#                     총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체           0.332697  0.445560  0.565364  0.458104
# scaled_cluster2  0.370675  0.444657  0.555086  0.420316
# cluster2_top5    0.356790  0.433659  0.535543  0.439569

# %%
pd.DataFrame([
    scaled_df.mean(), 
    scaled_cluster_3.mean(), 
    (scaled_cluster_3.loc[top_5.index[15:20], :]).mean()], 
    index = ['서울시 전체', 'scaled_cluster3', 'cluster3_top5'])
# Out:
#                    미세먼지지수       공원수  도시농업(프로그램수)  거주_유동_인구당_매출액     채소가게수  \
# 서울시 전체           0.041083  0.162784     0.023901       0.077117  0.038678
# scaled_cluster3  0.109606  0.115385     0.038605       0.111226  0.039981
# cluster3_top5    0.101115  0.100000     0.000000       0.126116  0.020930
#
#                  제로웨이스트 가게수  승하차인원_버스_지하철       카페수  유치원_초등학교       인구수  \
# 서울시 전체             0.020521      0.152383  0.127778  0.218402  0.440374
# scaled_cluster3    0.045957      0.235512  0.224104  0.205114  0.311474
# cluster3_top5      0.064516      0.162631  0.266995  0.229156  0.320518
#
#                     총_10대  총_20_30대   총_60대이상      1인세대
# 서울시 전체           0.332697  0.445560  0.565364  0.458104
# scaled_cluster3  0.204914  0.604845  0.484293  0.735352
# cluster3_top5    0.253403  0.609483  0.484706  0.687467
