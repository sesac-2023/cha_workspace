# %% [markdown]
# ### 1. 각 군집의 centroid 부터 거리 계산 (주성분 활용)

# %%
import pandas as pd
import numpy as np

pca_result = pd.read_csv('./data/minmax_scaling_PCA_label.csv', index_col=0)

# kmeans centroid numpy array 불러오기
centroids = np.load('./data/kmeans_centroid.npy')

# %%
# 클러스터 레이블 별로 데이터프레임 나누기
pca_cluster_0 = pca_result[pca_result['cluster'] == 0]
pca_cluster_1 = pca_result[pca_result['cluster'] == 1]
pca_cluster_2 = pca_result[pca_result['cluster'] == 2]
pca_cluster_3 = pca_result[pca_result['cluster'] == 3]

# %%
# 거리 계산 함수 생성
def calculate_distance(a, b):
    distance = 0
    for i in range(len(a)):
        distance += (a[i] - b[i]) ** 2
    return distance ** 0.5

# %%
# 오류 메시지 비활성화
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
# 각 cluster centroid로부터 떨어진 거리 계산 -> 'distance' 컬럼
pca_clusters = [pca_cluster_0, pca_cluster_1, pca_cluster_2, pca_cluster_3]

for i, pca_cluster in enumerate(pca_clusters):
    tmp = pca_cluster.drop('cluster', axis=1)
    distances = [calculate_distance(centroids[i], point) for point in tmp.values]
    pca_cluster.loc[:,'distance'] = distances

# %% [markdown]
# 클러스터별 최단 거리 순위 뽑아보기

# %%
pd.concat([
    pca_cluster_0.sort_values('distance').head(10),
    pca_cluster_1.sort_values('distance').head(10),
    pca_cluster_2.sort_values('distance').head(10),
    pca_cluster_3.sort_values('distance').head(10),
])
# Out:
#               0         1         2         3         4         5  cluster  \
# 행정동명
# 송파2동   0.079815 -0.244630  0.027826  0.015311 -0.039013 -0.010445        0
# 남가좌1동  0.088593 -0.312289  0.017162 -0.167120  0.047328  0.041055        0
# 하계2동   0.164587 -0.306063 -0.004596 -0.099306 -0.003715 -0.035986        0
# 방이1동  -0.056980 -0.250338  0.119408 -0.080721 -0.087399  0.055004        0
# 방배3동   0.100324 -0.300655  0.057266  0.061770  0.054492  0.053401        0
# 북가좌1동  0.057137 -0.308475 -0.032609 -0.141555  0.083661 -0.000781        0
# 신정2동   0.151606 -0.402561  0.063911 -0.196896  0.020415 -0.027373        0
# 신정1동   0.241651 -0.355673  0.155438 -0.083979  0.017424  0.061489        0
# 신도림동   0.056277 -0.173492  0.169507 -0.019930  0.046107 -0.125518        0
# 도곡1동  -0.105884 -0.275753  0.189327 -0.028677  0.014360 -0.034947        0
# 면목4동  -0.075829 -0.078424 -0.163650  0.052472  0.042259  0.000171        1
# 암사1동  -0.065351 -0.064685 -0.098996 -0.018784  0.066846  0.051345        1
# 홍제3동  -0.044947 -0.102270 -0.078139  0.104911  0.052648 -0.021009        1
# 화곡2동  -0.077616 -0.105319 -0.091817 -0.046530 -0.033173  0.018272        1
# 왕십리2동 -0.095186 -0.099579 -0.080063 -0.030630 -0.046733  0.044464        1
# 대림1동  -0.216808 -0.082659 -0.097490  0.074461  0.046871 -0.024300        1
# 쌍문2동  -0.060073 -0.093252 -0.120254  0.052367  0.110332 -0.058693        1
# 후암동   -0.173475 -0.012163 -0.079110 -0.033911 -0.037622 -0.009051        1
# 신길3동  -0.131739 -0.134882 -0.111894  0.042459 -0.003476 -0.094840        1
# 묵2동   -0.124423 -0.064610 -0.176403  0.043805 -0.024065 -0.075568        1
# 응암1동   0.340923  0.146296 -0.036382 -0.043997  0.010936 -0.063194        2
# 공항동    0.234698  0.127700  0.074049  0.056836 -0.034086  0.019892        2
# 은천동    0.292253  0.173590 -0.085477  0.054455 -0.064382 -0.050564        2
# 장안2동   0.335295  0.068695 -0.013889 -0.043233  0.007422 -0.085243        2
# 홍은2동   0.241983  0.094071 -0.057664 -0.008708  0.075267 -0.032089        2
# 남가좌2동  0.238374  0.081855 -0.041811 -0.055084  0.002293 -0.052122        2
# 묵1동    0.385948  0.068431 -0.119104 -0.021009  0.015168  0.014020        2
# 미성동    0.264827  0.142706 -0.110842  0.078237  0.050086  0.063293        2
# 흑석동    0.274764  0.047456  0.045378  0.099913 -0.081756 -0.093310        2
# 신정4동   0.296534  0.232400 -0.021534  0.134616 -0.052848  0.087269        2
# 연남동   -0.279381  0.241751  0.054741 -0.141780 -0.030941  0.037321        3
# 청파동   -0.192223  0.245593  0.034787 -0.019479 -0.086504 -0.016093        3
# 대흥동   -0.293714  0.241550  0.094023 -0.045394 -0.137476 -0.093218        3
# 합정동   -0.215536  0.204466  0.044690 -0.140127 -0.039214  0.076269        3
# 혜화동   -0.219628  0.222779  0.197047 -0.057721 -0.074808 -0.047043        3
# 구로5동  -0.253796  0.123504  0.062825 -0.058777 -0.028850 -0.014961        3
# 안암동   -0.342708  0.366326  0.051996 -0.196754 -0.117258 -0.012111        3
# 논현1동  -0.421358  0.317868  0.146901 -0.144606 -0.079735  0.009832        3
# 원효로1동 -0.160246  0.170086  0.021923 -0.084611 -0.124997  0.058906        3
# 이문1동  -0.201939  0.210990 -0.085376 -0.126060 -0.076727  0.015205        3
#
#        distance
# 행정동명
# 송파2동   0.143294
# 남가좌1동  0.158830
# 하계2동   0.163167
# 방이1동   0.168104
# 방배3동   0.173730
# 북가좌1동  0.193131
# 신정2동   0.194070
# 신정1동   0.195680
# 신도림동   0.197246
# 도곡1동   0.200085
# 면목4동   0.089658
# 암사1동   0.093978
# 홍제3동   0.110024
# 화곡2동   0.112856
# 왕십리2동  0.113090
# 대림1동   0.123150
# 쌍문2동   0.123322
# 후암동    0.123894
# 신길3동   0.127600
# 묵2동    0.129657
# 응암1동   0.121328
# 공항동    0.123388
# 은천동    0.133971
# 장안2동   0.138741
# 홍은2동   0.156357
# 남가좌2동  0.159507
# 묵1동    0.161121
# 미성동    0.163214
# 흑석동    0.170124
# 신정4동   0.174637
# 연남동    0.110855
# 청파동    0.114260
# 대흥동    0.146279
# 합정동    0.157352
# 혜화동    0.157554
# 구로5동   0.169749
# 안암동    0.195210
# 논현1동   0.198837
# 원효로1동  0.203055
# 이문1동   0.208322

# %%
pd.concat([
    pca_cluster_0.sort_values('distance').head(10),
    pca_cluster_1.sort_values('distance').head(10),
    pca_cluster_2.sort_values('distance').head(10),
    pca_cluster_3.sort_values('distance').head(10),
]).to_csv('./data/disance_test_.csv')

# %%
pd.concat([
    pca_cluster_0.sort_values('distance').tail(),
    pca_cluster_1.sort_values('distance').tail(),
    pca_cluster_2.sort_values('distance').tail(),
    pca_cluster_3.sort_values('distance').tail(),
])
# Out:
#                     0         1         2         3         4         5  \
# 행정동명
# 목1동          0.507268 -0.214312  0.227239 -0.252924  0.120060 -0.197872
# 개포3동        -0.329338 -0.412075  0.324227 -0.089670 -0.194497  0.235409
# 잠실2동         0.591298 -0.279213  0.125718 -0.294675 -0.033904 -0.133076
# 개포1동        -0.406954 -0.559747  0.268320 -0.067676 -0.161930  0.055800
# 명일2동        -0.221879 -0.561661  0.410790  0.097726 -0.351088 -0.127095
# 창신1동        -0.560045 -0.131278 -0.074370  0.290240 -0.024362 -0.121399
# 삼청동         -0.450803 -0.129602  0.112984 -0.239601  0.169397  0.231235
# 반포본동        -0.460108 -0.237586  0.169248 -0.017054 -0.275882  0.092829
# 가회동         -0.504886 -0.262278  0.297243  0.011905 -0.145766  0.042140
# 수서동         -0.447690 -0.215394  0.061619  0.637275 -0.077494 -0.178638
# 가양1동         0.250883  0.679489  0.192243 -0.057842 -0.158608  0.190651
# 목5동          0.794465 -0.258356  0.223936 -0.020476 -0.151098 -0.074822
# 세곡동          0.297409 -0.066953  0.401977  0.399429 -0.182665  0.366120
# 여의동          0.429205  0.353769  0.539371  0.022997  0.372315 -0.317041
# 양재1동         0.793389  0.260735  0.365653  0.408048 -0.068085  0.375711
# 둔촌1동        -0.621720 -0.141444  0.188045 -0.126260 -0.362875  0.062102
# 필동          -0.660355 -0.048411  0.392070  0.419604 -0.405873 -0.258607
# 명동          -0.523548  0.380905  0.775273  0.175097  0.416959  0.214580
# 서교동          0.031945  0.882373  0.650519 -0.093045  0.266645 -0.126773
# 종로1.2.3.4가동 -0.549133  0.754336  1.115468  0.628705  0.727712 -0.291113
#
#              cluster  distance
# 행정동명
# 목1동                0  0.543294
# 개포3동               0  0.553172
# 잠실2동               0  0.581037
# 개포1동               0  0.588373
# 명일2동               0  0.633971
# 창신1동               1  0.541552
# 삼청동                1  0.555763
# 반포본동               1  0.567465
# 가회동                1  0.612990
# 수서동                1  0.755028
# 가양1동               2  0.644186
# 목5동                2  0.662322
# 세곡동                2  0.695344
# 여의동                2  0.775565
# 양재1동               2  0.798233
# 둔촌1동               3  0.663973
# 필동                 3  0.892370
# 명동                 3  0.933855
# 서교동                3  0.937082
# 종로1.2.3.4가동        3  1.585267

# %% [markdown]
# ### 2. stanine을 이용해서 클러스터별 등급 매기기

# %%
import pandas as pd
import numpy as np

pca_result = pd.read_csv('./data/minmax_scaling_PCA_label.csv', index_col=0)
scaled_df = pd.read_csv('./data/minmax_scaling.csv', index_col=0)
original_df = pd.read_csv('./data/final_data_after_winsorization_with_selected_features.csv', index_col=0)

# %% [markdown]
# ## 최종 입지 선정
