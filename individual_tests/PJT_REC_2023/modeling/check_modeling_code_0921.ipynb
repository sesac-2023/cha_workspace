# %%
from modeling import load_data, load_doc2vec, show_similar_results

# %%
data = load_data()
model = load_doc2vec()

# %%
data
# Out:
#         cat2_id cat1_name cat2_name platform_name  \
# 0         10301        경제        금융            다음
# 1         10301        경제        금융            다음
# 2         10301        경제        금융            다음
# 3         10301        경제        금융            다음
# 4         10301        경제        금융            다음
# ...         ...       ...       ...           ...
# 310088    10315        경제      국제경제            다음
# 310089    10315        경제      국제경제            다음
# 310090    10315        경제      국제경제            다음
# 310091    10315        경제      국제경제            다음
# 310092    10315        경제      국제경제            다음
#
#                                             title    press  \
# 0                       토스뱅크 `먼저 이자받는 정기예금` 4조 돌파   디지털타임스
# 1                    실손보험 청구 간소화법, 국회 법사위 계류‥ 재논의   파이낸셜뉴스
# 2                “진작에 막차 탈걸”…50년 주담대 대출 한도 결국 줄인다     매일경제
# 3       [가계대출 냉·온탕 대책] 가계대출 폭증 원인 `50년 주담대` 한도 축소   디지털타임스
# 4                      SK이노 유증 청약 미달…실권주에 뭉칫돈 모일까      뉴시스
# ...                                           ...      ...
# 310088   승승장구 테슬라, 이제는 매도할 때?…"최근 2주간 가장 과매수된 종목"  SBS Biz
# 310089             테슬라 충전 시스템 '대세'…美 충전업체 너도나도 동참  SBS Biz
# 310090     美 자산운용사 "연준, 경기침체 발생하면 내년 초에 금리 인하할 것"  SBS Biz
# 310091      미 FTC, MS의 액티비전 인수 제지 위해 법원에 긴급가처분 소송   파이낸셜뉴스
# 310092            미 기대인플레 4.1% '2년래 최저'…금리 동결 기우나     이데일리
#
#                                writer          date_upload  \
# 0                                 이미선  2023-09-13 19:42:00
# 1                                 박소현  2023-09-13 19:08:00
# 2       문재용 기자(moon.jaeyong@mk.co.kr)  2023-09-13 19:03:00
# 3                                 김경렬  2023-09-13 19:50:00
# 4                              이지영 기자  2023-09-13 19:34:00
# ...                               ...                  ...
# 310088                      임선우 외신캐스터  2023-06-13 04:09:00
# 310089                      임선우 외신캐스터  2023-06-13 03:45:00
# 310090                      고유미 외신캐스터  2023-06-13 04:30:00
# 310091                            송경재  2023-06-13 04:09:00
# 310092                            김정남  2023-06-13 01:11:00
#
#                                                   content  \
# 0       토스뱅크는 인터넷전문은행 최초로 선보인 '먼저 이자 받는 정기예금'이 출시 170일...
# 1       [파이낸셜뉴스] 실손 보험금을 청구할 때 진료받은 병원에서 신청하면 전산으로 자동적...
# 2       주담대를 중심으로 가계대출이 급등조짐을 보이자 금융당국이 강도 높은 대출억제 정책을...
# 3       금융당국이 13일 발표한 가계부채 대책은 주택관련 대출을 정조준하고 있다. 부동산 ...
# 4       [서울=뉴시스]이지영 기자 = SK이노베이션의 1조1000억원 규모의 주주배정 유상...
# ...                                                   ...
# 310088  현지시간 11일 CNBC에 따르면 테슬라의 지난 2주간 상대강도지수(RSI)는 91...
# 310089  포드에 이어 제너럴모터스(GM)도 테슬라와의 '충전 동맹' 의사를 밝힌 뒤 미국 내...
# 310090  만 대표는 현지시간 9일 CNBC에 출연해 "지난 5월의 0.25%p 인상이 이번 ...
# 310091  미국 연방거래위원회(FTC)가 법원에 긴급가처분 소송을 낼 것으로 보인다. 마이크로...
# 310092  [뉴욕=이데일리 김정남 특파원] 미국 단기 기대인플레이션이 2년 만에 가장 낮은 수...
#
#                                                   sticker  \
# 0       "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 1       "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 2       "{'LIKE': 0, 'SAD': 0, 'ANGRY': 10, 'RECOMMEND...
# 3       "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 4       "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# ...                                                   ...
# 310088  "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 310089  "{'LIKE': 1, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 310090  "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 310091  "{'LIKE': 0, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
# 310092  "{'LIKE': 1, 'SAD': 0, 'ANGRY': 0, 'RECOMMEND'...
#
#                                            url
# 0       https://v.daum.net/v/20230913194214983
# 1       https://v.daum.net/v/20230913190804440
# 2       https://v.daum.net/v/20230913190300369
# 3       https://v.daum.net/v/20230913195046114
# 4       https://v.daum.net/v/20230913193457850
# ...                                        ...
# 310088  https://v.daum.net/v/20230613040900169
# 310089  https://v.daum.net/v/20230613034507083
# 310090  https://v.daum.net/v/20230613043004213
# 310091  https://v.daum.net/v/20230613040909173
# 310092  https://v.daum.net/v/20230613011109607
#
# [310093 rows x 11 columns]

# %%
column_list = ['title', 'date_upload', 'content', 'cos_simil']

# %%
show_similar_results(data=data, model=model, news_idx=10, column_list=column_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1618, in _iLocIndexer._get_list_axis(self, key, axis)
#    1617 try:
# -> 1618     return self.obj._take_with_is_copy(key, axis=axis)
#    1619 except IndexError as err:
#    1620     # re-raise with different error message
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\generic.py:3948, in NDFrame._take_with_is_copy(self, indices, axis)
#    3941 """
#    3942 Internal version of the `take` method that sets the `_is_copy`
#    3943 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3946 See the docstring of `take` for full explanation of the parameters.
#    3947 """
# -> 3948 result = self._take(indices=indices, axis=axis)
#    3949 # Maybe set copy if we didn't actually change the index.
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py:960, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     959 if convert_indices:
# --> 960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexers\utils.py:284, in maybe_convert_indices(indices, n, verify)
#     283     if mask.any():
# --> 284         raise IndexError("indices are out-of-bounds")
#     285 return indices
#
# IndexError: indices are out-of-bounds
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# c:\Users\user\Desktop\rec_pjt\데이터\test0921.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/rec_pjt/%EB%8D%B0%EC%9D%B4%ED%84%B0/test0921.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> show_similar_results(data=data, model=model, news_idx=10, column_list=column_list)
#
# File c:\Users\user\Desktop\rec_pjt\데이터\modeling.py:50, in show_similar_results(data, model, news_idx, column_list)
#      48 result = pd.DataFrame()
#      49 for idx, val in similar_docs:
# ---> 50     temp = data.iloc[[idx]].copy()
#      51     temp.loc[:, 'cos_simil'] = val
#      52     result = pd.concat([result, temp], axis=0)
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1647, in _iLocIndexer._getitem_axis(self, key, axis)
#    1645 # a list of integers
#    1646 elif is_list_like_indexer(key):
# -> 1647     return self._get_list_axis(key, axis=axis)
#    1649 # a single integer
#    1650 else:
#    1651     key = item_from_zerodim(key)
#
# File c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1621, in _iLocIndexer._get_list_axis(self, key, axis)
#    1618     return self.obj._take_with_is_copy(key, axis=axis)
#    1619 except IndexError as err:
#    1620     # re-raise with different error message
# -> 1621     raise IndexError("positional indexers are out-of-bounds") from err
#
# IndexError: positional indexers are out-of-bounds
