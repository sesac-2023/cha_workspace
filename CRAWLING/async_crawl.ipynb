# %% [markdown]
# # 비동기 방식 크롤링

# %% [markdown]
# 1. 클라이언트 HTML 문서를 먼저 불러온다.
# 2. 웹 API 서버에 데이터를 요청해서 추가적으로 화면을 구성
# - 개발자 도구 - Network 탭 - Fetch/XHR에서 확인

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.cine21.com/rank/boxoffice/domestic'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
movies = soup.select('#boxoffice_list_content')
movies
# Out:
# [<div id="boxoffice_list_content">
#  </div>]

# %% [markdown]
# 다른 방법 강구하기

# %%
url = 'http://www.cine21.com/rank/boxoffice/domestic_content'

data = {
    'page' : 9,
    'genre' : 'all',
    'period' : '2023-07-07'
}
response = requests.post(url, data=data)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
liTags = soup.select('.boxoffice_li')

for liTag in liTags:
    print(liTag.select_one('.mov_name').text.strip())
# Out:
# 두 여인
# 좀비 사용 설명서
# 해탄적일천
# 특별한 날
# 겨울 노래
# 퀴어 마이 프렌즈
# 룸 203
# SIWOLF2023-단편 경쟁1
# 나비 사냥
# 오타르 이오셀리아니 단편선
# 트래픽
# 거울 속 외딴 성
# 지옥만세
# 하얀봄
# 오! 나의 어시님
# 사슴의 왕
# 윌로씨의 휴가
# 워터 프론트
# 믿을 수 있는 사람
# 행복

# %% [markdown]
# ### JSON

# %%
import json

# %%
url = 'https://jsonplaceholder.typicode.com/posts'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)  # response.text (str) -> json으로 파싱 (dict으로 구성된 list)
print(type(response.text))
print(type(data))
# Out:
# <class 'str'>
# <class 'list'>

# %%
data[0]['title']
# Out:
# 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit'

# %% [markdown]
# ---
# # 실습

# %% [markdown]
# 네이버 웹툰 크롤링
# - 제목과 썸네일 이미지 url 가져오기
# - https://comic.naver.com/webtoon/weekday?order=User

# %%
# url = 'https://comic.naver.com/api/webtoon/titlelist/weekday?order=view'
url = 'https://comic.naver.com/api/webtoon/titlelist/weekday?order=user'  # 개발자 도구 - 네트워크탭 
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

# %%
for key, item in dict(data).items():
    print(key,item)
    break
# Out:
# data {'template': '<div class="ui job items segment company-list"><div class="ui blank filter segment"><div class="field checked">\n<!-- Generated by IcoMoon.io -->\n<svg version="1.1" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32">\n<title>check1</title>\n<path d="M12 21.56l-5.56-5.56-1.893 1.88 7.453 7.453 16-16-1.88-1.88-14.12 14.107z"></path>\n</svg>          <a data-query-add="sort=recent" href="/jobs?sort=recent">\n            <span>최신순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=ranking" href="/jobs?sort=ranking">\n            <span>인기순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=salary" href="/jobs?sort=salary">\n            <span>연봉순</span>\n          </a>\n        </div>\n</div>\n\n<div class="company item active" data-company_id="188886">\n  <div class="logo image">\n    <a href="/companies/path-1/jobs" target="_blank">\n      <div class="ui logo">\n        <img src="https://image.rocketpunch.com/company/188886/path-1_logo_1684755375.png?s=100x100&amp;t=inside" alt="패쓰 logo" class="ui image">\n      </div>\n    </a>
# %%
# data output
#  {'titleListMap': {'WEDNESDAY': [{'titleId': 769209,
#     'titleName': '화산귀환',
#     'author': 'LICO / 비가',
#     'thumbnailUrl': 'https://image-comic.pstatic.net/webtoon/769209/thumbnail/thumbnail_IMAG21_3511dcdd-6e33-4171-8839-598d6d266215.jpg',
#     'up': False,
#     'rest': False,
#     'bm': False,
#     'adult': False,
#     'starScore': 9.92877,
#     'viewCount': 0,
#     'openToday': False,
#     'potenUp': False,
#     'bestChallengeLevelUp': False,
#     'finish': False,
#     'new': False},

# %%
webtoons = []
for key in data['titleListMap']:  # 요일
    for webtoon in data['titleListMap'][key]:   # 해당 요일의 웹툰 정보들
        webtoon['titleName']   # 제목
        webtoon['thumbnailUrl']  # 썸네일 url

        webtoons.append({
            '제목' : webtoon['titleName'],
            '썸네일' :  webtoon['thumbnailUrl']
        })

        if len(webtoons) >= 5:
                break

    if len(webtoons) >= 5:
        break

webtoons
# Out:
# [{'제목': '화산귀환',
#   '썸네일': 'https://image-comic.pstatic.net/webtoon/769209/thumbnail/thumbnail_IMAG21_3511dcdd-6e33-4171-8839-598d6d266215.jpg'},
#  {'제목': '무직백수 계백순',
#   '썸네일': 'https://image-comic.pstatic.net/webtoon/811721/thumbnail/thumbnail_IMAG21_9a2a959a-666b-4156-8e4f-db64dfe319c6.jpg'},
#  {'제목': '전지적 독자 시점',
#   '썸네일': 'https://image-comic.pstatic.net/webtoon/747269/thumbnail/thumbnail_IMAG21_aabd9952-ff45-47a2-a543-33f19a5c6708.jpg'},
#  {'제목': '성스러운 작가생활',
#   '썸네일': 'https://image-comic.pstatic.net/webtoon/807859/thumbnail/thumbnail_IMAG21_f76458b0-e807-480e-b44c-3437d9888a75.jpg'},
#  {'제목': '헬퍼 2 : 킬베로스',
#   '썸네일': 'https://image-comic.pstatic.net/webtoon/670143/thumbnail/thumbnail_IMAG21_12d5d293-d54d-4022-8e00-c97c5779c701.jpg'}]

# %% [markdown]
# ---

# %% [markdown]
# 디자인정글 크롤링
# - 제목, 카테고리
# - 스크롤을 통해 나오는 추가 데이터도 크롤링
# - https://www.jungle.co.kr/

# %%
url = 'https://www.jungle.co.kr/recent.json'

# 쿼리파라미터
params = {
    'magazineOffset': 0,
    'contestOffset': 0,
    'exhibitOffset': 0,
    'galleryOffset': 0
}

response = requests.get(url, params=params)
data = json.loads(response.text)

# %%
data
# Out:
# {'exhibitOffset': 0,
#  'existMore': True,
#  'contestOffset': 6,
#  'success': True,
#  'galleryOffset': 0,
#  'moreList': [{'id': 206061,
#    'title': '2023 가명정보활용우수사례*아이디어 경진대회',
#    'thumbnailImageId': 'a11c950b4e779e3ce565921b',
#    'secondaryThumbnailImageId': '7a63ddb74d7a9d7e3d760f91',
#    'confirmedDate': '23-07-14',
#    'originalCreatedDate': 1689321703000,
#    'targetCode': '공모전',
#    'targetName': 'contest'},
#   {'id': 206060,
#    'title': '[한국청년기업가정신재단] 제 10회 기업가정신 콘텐츠 공모전 (~8/17)',
#    'thumbnailImageId': '8621b23542fa8e9f44f45ad8',
#    'secondaryThumbnailImageId': '1fcf81d74e02acc26175df67',
#    'confirmedDate': '23-07-14',
#    'originalCreatedDate': 1689320586000,
#    'targetCode': '공모전',
#    'targetName': 'contest'},
#   {'id': 206059,
#    'title': '2023 경북글로벌게임센터 서포터즈 경글이 6기 모집',
#    'thumbnailImageId': 'cfc5e0554286b621411cea7e',
#    'secondaryThumbnailImageId': '4aaf94da4a7eb95f8efa3319',
#    'confirmedDate': '23-07-14',
#    'originalCreatedDate': 1689303478000,
#    'targetCode': '공모전',
#    'targetName': 'contest'},
#   {'id': 206058,
#    'title': '[에코프로] 대학생 봉사단_에코브리지 4기 모집',
#    'thumbnailImageId': 'e6567cdd466282d2ac433eb9',
#    'secondaryThumbnailImageId': '5c603f184987acf57e1aa1b9',
#    'confirmedDate': '23-07-14',
#    'originalCreatedDate': 1689298454000,
#    'targetCode': '공모전',
#    'targetName': 'contest'},
#   {'id': 206057,
#    'title': 'Try everything 2023 전국민 창업 오디션',
#    'thumbnailImageId': '54ae7817452bb9be17b754c3',
#    'secondaryThumbnailImageId': '2958728d49ea8df007c1ffcc',
#    'confirmedDate': '23-07-14',
#    'originalCreatedDate': 1689294130000,
#    'targetCode': '공모전',
#    'targetName': 'contest'},
#   {'id': 206056,
#    'title': '[대구, 경북지역] 비영리 마케팅',
#    'thumbnailImageId': '3d7cf83f4f11afe1229c9693',
#    'secondaryThumbnailImageId': 'a7215c7b4cab8bb209dba9f5',
#    'confirmedDate': '23-07-13',
#    'originalCreatedDate': 1689241661000,
#    'targetCode': '공모전',
#    'targetName': 'contest'}],
#  'magazineOffset': 0}

# %%
result = []
while True:
    response = requests.get(url, params=params)
    data = json.loads(response.text)
    # for item in data['moreList']:
    #     params[item['targetName'] + 'Offset'] += 1  # 데이터의 params값이 주어지지 않을 때
    for key in params:
        params[key] = data[key]
    print(params)    

    # to do! break 문 추가하기
  
    for item in data['moreList']:
        result.append({
            '카테고리' : item['targetCode'],
            '제목' : item['title']
        })

    if len(result) >= 10:
        break
# Out:
# {'magazineOffset': 0, 'contestOffset': 6, 'exhibitOffset': 0, 'galleryOffset': 0}
# {'magazineOffset': 0, 'contestOffset': 12, 'exhibitOffset': 0, 'galleryOffset': 0}

# %%
result[:10]
# Out:
# [{'카테고리': '공모전', '제목': '2023 가명정보활용우수사례*아이디어 경진대회'},
#  {'카테고리': '공모전', '제목': '[한국청년기업가정신재단] 제 10회 기업가정신 콘텐츠 공모전 (~8/17)'},
#  {'카테고리': '공모전', '제목': '2023 경북글로벌게임센터 서포터즈 경글이 6기 모집'},
#  {'카테고리': '공모전', '제목': '[에코프로] 대학생 봉사단_에코브리지 4기 모집'},
#  {'카테고리': '공모전', '제목': 'Try everything 2023 전국민 창업 오디션'},
#  {'카테고리': '공모전', '제목': '[대구, 경북지역] 비영리 마케팅'},
#  {'카테고리': '공모전', '제목': '제47차\xa0HIMUN\xa0사회자∙서포터즈 모집 안내'},
#  {'카테고리': '공모전', '제목': 'KIMA WEEK 2023 서포터즈 모집 (7/13~30)'},
#  {'카테고리': '공모전', '제목': '제32회 대전디자인어워드 특별주제(꿈돌이 캐릭터 공모전)'},
#  {'카테고리': '공모전', '제목': '[풀스택-웹] 국비지원 풀스택 개발자 양성 과정 챗GPT활용'}]

# %% [markdown]
# ---

# %% [markdown]
# 로켓펀치 채용 크롤링
# - 회사명, 회사설명, 채용공고(회사 별 여러 개)
# - 총 10페이지를 크롤링해주세요.
# - https://www.rocketpunch.com/jobs
# - hint : HTML in JSON

# %%
url = 'https://www.rocketpunch.com/api/jobs/template?page={}'

response = requests.get(url.format(2))
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'data': {'template': '<div class="ui job items segment company-list"><div class="ui blank filter segment"><div class="field checked">\n<!-- Generated by IcoMoon.io -->\n<svg version="1.1" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32">\n<title>check1</title>\n<path d="M12 21.56l-5.56-5.56-1.893 1.88 7.453 7.453 16-16-1.88-1.88-14.12 14.107z"></path>\n</svg>          <a data-query-add="sort=recent" href="/jobs?sort=recent">\n            <span>최신순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=ranking" href="/jobs?sort=ranking">\n            <span>인기순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=salary" href="/jobs?sort=salary">\n            <span>연봉순</span>\n          </a>\n        </div>\n</div>\n\n<div class="company item active" data-company_id="188886">\n  <div class="logo image">\n    <a href="/companies/path-1/jobs" target="_blank">\n      <div class="ui logo">\n        <img src="https://image.rocketpunch.com/company/188886/path-1_logo_1684755375.png?s=100x100&amp;t=inside" alt="패쓰 logo" class="ui image">\n      </div>\n    </a>\n  </div>\n  <div class="content active">\n\n    <div class="company-name">\n      <a href="/companies/path-1/jobs" target="_blank" class="company-name nowrap header name">\n        패쓰\n      </a>\n    </div>\n    <div class="description">AI 에듀웨어 플랫폼 &#34;패쓰&#34;&nbsp;</div>\n    <div class="job-badges" style="margin-top:8px;display:inline-flex;gap:4px">    <span class="reward-banner nowrap">\n<svg width="48" height="48" viewBox="0 0 48 48" fill="none" xmlns="http://www.w3.org/2000/svg">\n  <path fill-rule="evenodd" clip-rule="evenodd"\n    d="M24 44C35.0457 44 44 35.0457 44 24C44 12.9543 35.0457 4 24 4C12.9543 4 4 12.9543 4 24C4 35.0457 12.9543 44 24 44ZM30.0337 33.242L32.1462 24.359H35.2357C35.3237 24.359 35.4029 24.3332 35.4733 24.2817C35.5437 24.2131 35.5789 24.1444 35.5789 24.0757V22.3506C35.5789 22.1446 35.4645 22.0417 35.2357 22.0417H32.6743L34.153 15.9137C34.1882 15.7935 34.1882 15.7077 34.153 15.6562C34.1178 15.6047 33.9858 15.5789 33.7569 15.5789H31.7765C31.6533 15.5789 31.5653 15.5875 31.5125 15.6047C31.4596 15.6219 31.4156 15.6905 31.3804 15.8107L29.9281 22.0417H26.9971L25.4919 15.8107C25.4567 15.6905 25.4127 15.6219 25.3599 15.6047C25.3247 15.5875 25.2455 15.5789 25.1222 15.5789H22.9042C22.7809 15.5789 22.6929 15.5875 22.6401 15.6047C22.6049 15.6219 22.5697 15.6905 22.5345 15.8107L21.0293 22.0417H18.0983L16.646 15.8107C16.6108 15.6905 16.5668 15.6219 16.514 15.6047C16.4611 15.5875 16.3731 15.5789 16.2499 15.5789H14.2695C14.0406 15.5789 13.9086 15.6047 13.8734 15.6562C13.8382 15.7077 13.8382 15.7935 13.8734 15.9137L15.3521 22.0417H12.7643C12.6763 22.0417 12.5971 22.076 12.5267 22.1446C12.4563 22.1961 12.4211 22.2648 12.4211 22.3506V24.0757C12.4211 24.1444 12.4563 24.2131 12.5267 24.2817C12.5971 24.3332 12.6763 24.359 12.7643 24.359H15.8802L17.9927 33.242C18.0279 33.3621 18.0631 33.4308 18.0983 33.4479C18.1335 33.4651 18.2303 33.4737 18.3888 33.4737H20.4748C20.6685 33.4737 20.7741 33.4651 20.7917 33.4479C20.8269 33.4308 20.8621 33.3621 20.8973 33.242L23.0362 24.359H24.9902L27.1291 33.242C27.1643 33.3621 27.1907 33.4308 27.2083 33.4479C27.2435 33.4651 27.3579 33.4737 27.5516 33.4737H29.6376C29.7961 33.4737 29.8929 33.4651 29.9281 33.4479C29.9633 33.4308 29.9985 33.3621 30.0337 33.242ZM24.0132 20.3423L24.4093 22.0417H23.6171L24.0132 20.3423ZM29.4 24.359L28.5022 28.2211L27.578 24.359H29.4ZM20.4484 24.359L19.5242 28.2211L18.6264 24.359H20.4484Z"\n    fill="black" />\n</svg>        <span data-content="지원 후 합격시 로켓리워드를 지급하는 기업입니다." data-variation="inverted mini">\n            리워드 50만원\n        </span>\n    </span>\n<span class="ui small basic response label nowrap"><div data-content="7일 이내 지원 결과를 알려줄 확률이 70% 이상인 기업입니다." data-variation="inverted mini">응답률 우수</div></span></div>\n    <div class=" ...
#   'title': '채용 정보 | 로켓펀치 - 비즈니스 네트워크',
#   'seo_url': 'https://www.rocketpunch.com/jobs'},
#  'meta': {'code': 200}}

# %%
data['data']
# Out:
# {'template': '<div class="ui job items segment company-list"><div class="ui blank filter segment"><div class="field checked">\n<!-- Generated by IcoMoon.io -->\n<svg version="1.1" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32">\n<title>check1</title>\n<path d="M12 21.56l-5.56-5.56-1.893 1.88 7.453 7.453 16-16-1.88-1.88-14.12 14.107z"></path>\n</svg>          <a data-query-add="sort=recent" href="/jobs?sort=recent">\n            <span>최신순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=ranking" href="/jobs?sort=ranking">\n            <span>인기순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=salary" href="/jobs?sort=salary">\n            <span>연봉순</span>\n          </a>\n        </div>\n</div>\n\n<div class="company item active" data-company_id="188886">\n  <div class="logo image">\n    <a href="/companies/path-1/jobs" target="_blank">\n      <div class="ui logo">\n        <img src="https://image.rocketpunch.com/company/188886/path-1_logo_1684755375.png?s=100x100&amp;t=inside" alt="패쓰 logo" class="ui image">
#  'title': '채용 정보 | 로켓펀치 - 비즈니스 네트워크',
#  'seo_url': 'https://www.rocketpunch.com/jobs'}

# %%
html = data['data']['template']
html
# Out:
# '<div class="ui job items segment company-list"><div class="ui blank filter segment"><div class="field checked">\n<!-- Generated by IcoMoon.io -->\n<svg version="1.1" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32">\n<title>check1</title>\n<path d="M12 21.56l-5.56-5.56-1.893 1.88 7.453 7.453 16-16-1.88-1.88-14.12 14.107z"></path>\n</svg>          <a data-query-add="sort=recent" href="/jobs?sort=recent">\n            <span>최신순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=ranking" href="/jobs?sort=ranking">\n            <span>인기순</span>\n          </a>\n        </div>\n        <div class="divider"></div>\n<div class="field">\n          <a data-query-add="sort=salary" href="/jobs?sort=salary">\n            <span>연봉순</span>\n          </a>\n        </div>\n</div>\n\n<div class="company item active" data-company_id="188886">\n  <div class="logo image">\n    <a href="/companies/path-1/jobs" target="_blank">\n      <div class="ui logo">\n        <img src="https://image.rocketpunch.com/company/188886/path-1_logo_1684755375.png?s=100x100&amp;t=inside" alt="패쓰 logo" class="ui image">\n      </div>\n    </a>\n  </div>\n  <div class="content active">\n\n    <div class="company-name">\n      <a href="/companies/path-1/jobs" target="_blank" class="company-name nowrap header name">\n        패쓰\n      </a>\n    </div>\n    <div class="description">AI 에듀웨어 플랫폼 &#34;패쓰&#34;&nbsp;</div>\n    <div class="job-badges" style="margin-top:8px;display:inline-flex;gap:4px">    <span class="reward-banner nowrap">\n<svg width="48" height="48" viewBox="0 0 48 48" fill="none" xmlns="http://www.w3.org/2000/svg">\n  <path fill-rule="evenodd" clip-rule="evenodd"\n    d="M24 44C35.0457 44 44 35.0457 44 24C44 12.9543 35.0457 4 24 4C12.9543 4 4 12.9543 4 24C4 35.0457 12.9543 44 24 44ZM30.0337 33.242L32.1462 24.359H35.2357C35.3237 24.359 35.4029 24.3332 35.4733 24.2817C35.5437 24.2131 35.5789 24.1444 35.5789 24.0757V22.3506C35.5789 22.1446 35.4645 22.0417 35.2357 22.0417H32.6743L34.153 15.9137C34.1882 15.7935 34.1882 15.7077 34.153 15.6562C34.1178 15.6047 33.9858 15.5789 33.7569 15.5789H31.7765C31.6533 15.5789 31.5653 15.5875 31.5125 15.6047C31.4596 15.6219 31.4156 15.6905 31.3804 15.8107L29.9281 22.0417H26.9971L25.4919 15.8107C25.4567 15.6905 25.4127 15.6219 25.3599 15.6047C25.3247 15.5875 25.2455 15.5789 25.1222 15.5789H22.9042C22.7809 15.5789 22.6929 15.5875 22.6401 15.6047C22.6049 15.6219 22.5697 15.6905 22.5345 15.8107L21.0293 22.0417H18.0983L16.646 15.8107C16.6108 15.6905 16.5668 15.6219 16.514 15.6047C16.4611 15.5875 16.3731 15.5789 16.2499 15.5789H14.2695C14.0406 15.5789 13.9086 15.6047 13.8734 15.6562C13.8382 15.7077 13.8382 15.7935 13.8734 15.9137L15.3521 22.0417H12.7643C12.6763 22.0417 12.5971 22.076 12.5267 22.1446C12.4563 22.1961 12.4211 22.2648 12.4211 22.3506V24.0757C12.4211 24.1444 12.4563 24.2131 12.5267 24.2817C12.5971 24.3332 12.6763 24.359 12.7643 24.359H15.8802L17.9927 33.242C18.0279 33.3621 18.0631 33.4308 18.0983 33.4479C18.1335 33.4651 18.2303 33.4737 18.3888 33.4737H20.4748C20.6685 33.4737 20.7741 33.4651 20.7917 33.4479C20.8269 33.4308 20.8621 33.3621 20.8973 33.242L23.0362 24.359H24.9902L27.1291 33.242C27.1643 33.3621 27.1907 33.4308 27.2083 33.4479C27.2435 33.4651 27.3579 33.4737 27.5516 33.4737H29.6376C29.7961 33.4737 29.8929 33.4651 29.9281 33.4479C29.9633 33.4308 29.9985 33.3621 30.0337 33.242ZM24.0132 20.3423L24.4093 22.0417H23.6171L24.0132 20.3423ZM29.4 24.359L28.5022 28.2211L27.578 24.359H29.4ZM20.4484 24.359L19.5242 28.2211L18.6264 24.359H20.4484Z"\n    fill="black" />\n</svg>        <span data-content="지원 후 합격시 로켓리워드를 지급하는 기업입니다." data-variation="inverted mini">\n            리워드 50만원\n        </span>\n    </span>\n<span class="ui small basic response label nowrap"><div data-content="7일 이내 지원 결과를 알려줄 확률이 70% 이상인 기업입니다." data-variation="inverted mini">응답률 우수</div></span></div>\n    <div class="ui divider"></div>\n   ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
companyList = soup.select('.company.item')
len(companyList)
# Out:
# 20

# %%
rocket_result = []
for company in companyList:
    # company.select_one('.company-name').text.strip()
    # company.select_one('.description').text.strip()
    # [job.text.strip() for job in company.select_one('.job-name')]

    rocket_result.append({
        '회사명' : company.select_one('.company-name').text.strip(),
        '설명' : company.select_one('.description').text.strip(),
        # '공고 종류' : [(job.text.strip(), job.attrs['href']) for job in company.select('.job-name > a:first-child')]
        '공고 종류' : [(job.text.strip(), job.select_one('a').attrs['href']) for job in company.select('.job-name')]
    })

    if len(rocket_result) >= 5:
        break
  
rocket_result
# Out:
# [{'회사명': '패쓰',
#   '설명': 'AI 에듀웨어 플랫폼 "패쓰"',
#   '공고 종류': [('PM / PL / 서비스 기획 채용',
#     '/jobs/146181/PM-PL-%EC%84%9C%EB%B9%84%EC%8A%A4-%EA%B8%B0%ED%9A%8D-%EC%B1%84%EC%9A%A9'),
#    ('콘텐츠 마케터 채용',
#     '/jobs/146434/%EC%BD%98%ED%85%90%EC%B8%A0-%EB%A7%88%EC%BC%80%ED%84%B0-%EC%B1%84%EC%9A%A9'),
#    ('백엔드 개발자 (시니어 / 5년 이상)',
#     '/jobs/145324/%EB%B0%B1%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90-%EC%8B%9C%EB%8B%88%EC%96%B4-5%EB%85%84-%EC%9D%B4%EC%83%81'),
#    ('퍼포먼스 마케터 채용',
#     '/jobs/146433/%ED%8D%BC%ED%8F%AC%EB%A8%BC%EC%8A%A4-%EB%A7%88%EC%BC%80%ED%84%B0-%EC%B1%84%EC%9A%A9')]},
#  {'회사명': '블로세이프',
#   '설명': '전통 금융에서 블록체인 기반의 분산화 금융으로 , 금융 시스템의 패러다임을 바꾸는 것을 목표로 설립된 전문 블록체인 회사입니다.',
#   '공고 종류': [('시스템인프라 개발자',
#     '/jobs/145307/%EC%8B%9C%EC%8A%A4%ED%85%9C%EC%9D%B8%ED%94%84%EB%9D%BC-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('No! 출근! 고빈도 거래 시스템 개발자(High Frequency Trading)',
#     '/jobs/143879/No-%EC%B6%9C%EA%B7%BC-%EA%B3%A0%EB%B9%88%EB%8F%84-%EA%B1%B0%EB%9E%98-%EC%8B%9C%EC%8A%A4%ED%85%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90High-Frequency-Trading'),
#    ('No출근! 주2회 재택 프론트엔드',
#     '/jobs/146431/No%EC%B6%9C%EA%B7%BC-%EC%A3%BC2%ED%9A%8C-%EC%9E%AC%ED%83%9D-%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C'),
#    ('No출근! 주2회 재택 백엔드 개발자',
#     '/jobs/146432/No%EC%B6%9C%EA%B7%BC-%EC%A3%BC2%ED%9A%8C-%EC%9E%AC%ED%83%9D-%EB%B0%B1%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('No! 출근 업계 최대 연봉    (퀀트 리서처 모집)',
#     '/jobs/145303/No-%EC%B6%9C%EA%B7%BC-%EC%97%85%EA%B3%84-%EC%B5%9C%EB%8C%80-%EC%97%B0%EB%B4%89-%ED%80%80%ED%8A%B8-%EB%A6%AC%EC%84%9C%EC%B2%98-%EB%AA%A8%EC%A7%91')]},
#  {'회사명': '모아이스',
#   '설명': '인공지능 기술을 이용하여 스포츠 교육 및 연습에 도움을 주는 솔루션을 개발하는 회사',
#   '공고 종류': [('AI Research Engineer(2D Pose Estimation)',
#     '/jobs/145447/AI-Research-Engineer2D-Pose-Estimation'),
#    ('사업관리(경력)',
#     '/jobs/146430/%EC%82%AC%EC%97%85%EA%B4%80%EB%A6%AC%EA%B2%BD%EB%A0%A5')]},
#  {'회사명': '오이스터에이블',
#   '설명': '오이스터에이블은 지구환경을 지키고 실천하는 히어로에게 보람과 성취를 드리는 순환경제 서비스와 인프라를 제공합니다.',
#   '공고 종류': [('지구를 구하는 주니어 웹 프론트 엔드 개발자를 찾습니다!',
#     '/jobs/144233/%EC%A7%80%EA%B5%AC%EB%A5%BC-%EA%B5%AC%ED%95%98%EB%8A%94-%EC%A3%BC%EB%8B%88%EC%96%B4-%EC%9B%B9-%ED%94%84%EB%A1%A0%ED%8A%B8-%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90%EB%A5%BC-%EC%B0%BE%EC%8A%B5%EB%8B%88%EB%8B%A4'),
#    ('지구를 지키는 사업개발 및 기획 PM을 찾습니다!',
#     '/jobs/145623/%EC%A7%80%EA%B5%AC%EB%A5%BC-%EC%A7%80%ED%82%A4%EB%8A%94-%EC%82%AC%EC%97%85%EA%B0%9C%EB%B0%9C-%EB%B0%8F-%EA%B8%B0%ED%9A%8D-PM%EC%9D%84-%EC%B0%BE%EC%8A%B5%EB%8B%88%EB%8B%A4'),
#    ('지구를 구하는 주니어 플러터 개발자를 찾습니다!',
#     '/jobs/144232/%EC%A7%80%EA%B5%AC%EB%A5%BC-%EA%B5%AC%ED%95%98%EB%8A%94-%EC%A3%BC%EB%8B%88%EC%96%B4-%ED%94%8C%EB%9F%AC%ED%84%B0-%EA%B0%9C%EB%B0%9C%EC%9E%90%EB%A5%BC-%EC%B0%BE%EC%8A%B5%EB%8B%88%EB%8B%A4')]},
#  {'회사명': '카이헬스',
#   '설명': '카이헬스는 최상의 배아로 건강한 아기를 가질 수 있도록 돕는 난임 인공지능 솔루션 회사입니다.',
#   '공고 종류': [('정부과제 R&D 과제 담당자 채용 계약직(1명)',
#     '/jobs/146134/%EC%A0%95%EB%B6%80%EA%B3%BC%EC%A0%9C-RD-%EA%B3%BC%EC%A0%9C-%EB%8B%B4%EB%8B%B9%EC%9E%90-%EC%B1%84%EC%9A%A9-%EA%B3%84%EC%95%BD%EC%A7%811%EB%AA%85'),
#    ('AI 엔지니어 계약직',
#     '/jobs/146329/AI-%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4-%EA%B3%84%EC%95%BD%EC%A7%81'),
#    ('AI 총괄매니저',
#     '/jobs/146330/AI-%EC%B4%9D%EA%B4%84%EB%A7%A4%EB%8B%88%EC%A0%80'),
#    ('AI 의료 데이터 분석가 (1명)',
#     '/jobs/146131/AI-%EC%9D%98%EB%A3%8C-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EB%B6%84%EC%84%9D%EA%B0%80-1%EB%AA%85')]}]

# %%
def crawl_rocketpunch(page):
    response = requests.get(url.format(page))
    data = json.loads(response.text)
    html = data['data']['template']
    soup = BeautifulSoup(html, 'html.parser')
    companyList = soup.select('.company.item')

    rocket_result = []
    for company in companyList:
        # company.select_one('.company-name').text.strip()
        # company.select_one('.description').text.strip()
        # [job.text.strip() for job in company.select_one('.job-name')]

        rocket_result.append({
            '회사명' : company.select_one('.company-name').text.strip(),
            '설명' : company.select_one('.description').text.strip(),
            # '공고 종류' : [(job.text.strip(), job.attrs['href']) for job in company.select('.job-name > a:first-child')]
            '공고 종류' : [(job.text.strip(), job.select_one('a').attrs['href']) for job in company.select('.job-name')]
        })
    
    return rocket_result

# %%
rocket_result = []
for page in range(1, 3):
    rocket_result.extend(crawl_rocketpunch(page))

# %%
rocket_result[:5]
# Out:
# [{'회사명': '텐큐브',
#   '설명': '텐큐브는 데이터 수집, 분석 기술을 기반으로 사용자의 불편을 해결하고 좋은 제품을 만듭니다.',
#   '공고 종류': []},
#  {'회사명': 'ABC Studio', '설명': '베트남 스타일 콘텐츠 커머스', '공고 종류': []},
#  {'회사명': '비트바이트',
#   '설명': '비트바이트는 모바일 키보드 입력을 더 편리하고 즐겁게 변화시킴으로써 우리의 ‘행복한 일상’을 만듭니다. 매일 150개국에서 사용하는 글로벌 서드파티 키보드, 플레이키보드를 서비스합니다.',
#   '공고 종류': []},
#  {'회사명': '로켓펀치', '설명': '한국 최대 비즈니스 소셜 네트워크', '공고 종류': []},
#  {'회사명': '아이팩토리',
#   '설명': 'IP(Intellectual Property) 관련 소프트웨어 개발 스타트업',
#   '공고 종류': [('글로벌 서비스 IPEDIT과 세계로 함께 진출 할 프론트엔드 개발자 모집 (Vue.js)',
#     '/jobs/146453/%EA%B8%80%EB%A1%9C%EB%B2%8C-%EC%84%9C%EB%B9%84%EC%8A%A4-IPEDIT%EA%B3%BC-%EC%84%B8%EA%B3%84%EB%A1%9C-%ED%95%A8%EA%BB%98-%EC%A7%84%EC%B6%9C-%ED%95%A0-%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90-%EB%AA%A8%EC%A7%91-Vuejs')]}]

# %%
def crawl_rocketpunch(page):
    response = requests.get(url.format(page))
    data = json.loads(response.text)
    html = data['data']['template']
    soup = BeautifulSoup(html, 'html.parser')
    company_list = soup.select('.company.item')

    rocket_result = []
    for company in company_list:
        company.select_one('.company-name').text.strip()
        company.select_one('.description').text.strip()
        [job.text.strip() for job in company.select('.job-name')]

        rocket_result.append({
            '회사명': company.select_one('.company-name').text.strip(),
            '설명': company.select_one('.description').text.strip(),

            # '공고들': [(job.text.strip(), job.attrs['href']) for job in company.select('.job-name > a:first-child')],
            '공고들': [(job.text.strip(), job.select_one('a').attrs['href']) for job in company.select('.job-name')],
        })

    return rocket_result

# %%
rocket_result = []
for page in range(1, 3):
    rocket_result.extend(crawl_rocketpunch(page))

    if len(rocket_result) >= 1:
        break

rocket_result
# Out:
# [{'회사명': '비트바이트',
#   '설명': '비트바이트는 모바일 키보드 입력을 더 편리하고 즐겁게 변화시킴으로써 우리의 ‘행복한 일상’을 만듭니다. 매일 150개국에서 사용하는 글로벌 서드파티 키보드, 플레이키보드를 서비스합니다.',
#   '공고들': []},
#  {'회사명': '로켓펀치', '설명': '한국 최대 비즈니스 소셜 네트워크', '공고들': []},
#  {'회사명': 'ABC Studio', '설명': '베트남 스타일 콘텐츠 커머스', '공고들': []},
#  {'회사명': '텐큐브',
#   '설명': '텐큐브는 데이터 수집, 분석 기술을 기반으로 사용자의 불편을 해결하고 좋은 제품을 만듭니다.',
#   '공고들': []},
#  {'회사명': '아이팩토리',
#   '설명': 'IP(Intellectual Property) 관련 소프트웨어 개발 스타트업',
#   '공고들': [('글로벌 서비스 IPEDIT과 세계로 함께 진출 할 프론트엔드 개발자 모집 (Vue.js)',
#     '/jobs/146453/%EA%B8%80%EB%A1%9C%EB%B2%8C-%EC%84%9C%EB%B9%84%EC%8A%A4-IPEDIT%EA%B3%BC-%EC%84%B8%EA%B3%84%EB%A1%9C-%ED%95%A8%EA%BB%98-%EC%A7%84%EC%B6%9C-%ED%95%A0-%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90-%EB%AA%A8%EC%A7%91-Vuejs')]},
#  {'회사명': '주식회사 클라썸',
#   '설명': '학습자와 교육자를 이어주는 인터랙티브 학습 플랫폼',
#   '공고들': [('앱(React Native) 개발자',
#     '/jobs/119621/%EC%95%B1React-Native-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('백엔드(Node.js) 개발자',
#     '/jobs/119622/%EB%B0%B1%EC%97%94%EB%93%9CNodejs-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('B2B 마케터', '/jobs/119628/B2B-%EB%A7%88%EC%BC%80%ED%84%B0'),
#    ('HRD 사업 개발 및 운영 인턴',
#     '/jobs/140822/HRD-%EC%82%AC%EC%97%85-%EA%B0%9C%EB%B0%9C-%EB%B0%8F-%EC%9A%B4%EC%98%81-%EC%9D%B8%ED%84%B4')]},
#  {'회사명': '몬드리안에이아이 (주)',
#   '설명': '인공지능/머신러닝, 데이터분석, 데이터 시각화 전문 기업',
#   '공고들': [('UI/UX 디자이너',
#     '/jobs/140941/UIUX-%EB%94%94%EC%9E%90%EC%9D%B4%EB%84%88'),
#    ('프론트엔드 개발자',
#     '/jobs/143369/%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('프론트엔드 개발자',
#     '/jobs/143368/%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90'),
#    ('AI 연구원', '/jobs/146452/AI-%EC%97%B0%EA%B5%AC%EC%9B%90')]},
#  {'회사명': '트레바리',
#   '설명': '읽고, 쓰고, 대화하고, 친해져요!',
#   '공고들': [('커뮤니티 운영 · 기획',
#     '/jobs/145509/%EC%BB%A4%EB%AE%A4%EB%8B%88%ED%8B%B0-%EC%9A%B4%EC%98%81-%C2%B7-%EA%B8%B0%ED%9A%8D')]},
#  {'회사명': '푸드트래블',
#   '설명': "대한민국 NO.1 푸드트럭 단체주문 플랫폼 '기프트럭'",
#   '공고들': [('서비스 기획 (마케팅 PM)',
#     '/jobs/146449/%EC%84%9C%EB%B9%84%EC%8A%A4-%EA%B8%B0%ED%9A%8D-%EB%A7%88%EC%BC%80%ED%8C%85-PM'),
#    ('F&B상품 기획 (PM)',
#     '/jobs/146450/FB%EC%83%81%ED%92%88-%EA%B8%B0%ED%9A%8D-PM'),
#    ('운영 기획', '/jobs/146451/%EC%9A%B4%EC%98%81-%EA%B8%B0%ED%9A%8D'),
#    ('서비스 기획 (단체주문 PM)',
#     '/jobs/146448/%EC%84%9C%EB%B9%84%EC%8A%A4-%EA%B8%B0%ED%9A%8D-%EB%8B%A8%EC%B2%B4%EC%A3%BC%EB%AC%B8-PM')]},
#  {'회사명': '에피소든',
#   '설명': '화상통신기술을 활용한 글로벌영어회화서비스',
#   '공고들': [('글로벌 영어회화 서비스 에피소든 Product Owner 겸 그로스해킹 담당자',
#     '/jobs/142064/%EA%B8%80%EB%A1%9C%EB%B2%8C-%EC%98%81%EC%96%B4%ED%9A%8C%ED%99%94-%EC%84%9C%EB%B9%84%EC%8A%A4-%EC%97%90%ED%94%BC%EC%86%8C%EB%93%A0-Product-Owner-%EA%B2%B8-%EA%B7%B8%EB%A1%9C%EC%8A%A4%ED%95%B4%ED%82%B9-%EB%8B%B4%EB%8B%B9%EC%9E%90'),
#    ('글로벌 영어회화 서비스 Episoden 백엔드 개발자 채용',
#     '/jobs/146447/%EA%B8%80%EB%A1%9C%EB%B2%8C-%EC%98%81%EC%96%B4%ED%9A%8C%ED%99%94-%EC%84%9C%EB%B9%84%EC%8A%A4-Episoden-%EB%B0%B1%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%
EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C10%EB%85%84'),
#    ('모빌리티의 미래를 그릴 분들을 모십니다. (기획/PM)',
#     '/jobs/146243/%EB%AA%A8%EB%B9%8C%EB%A6%AC%ED%8B%B0%EC%9D%98-%EB%AF%B8%EB%9E%98%EB%A5%BC-%EA%B7%B8%EB%A6%B4-%EB%B6%84%EB%93%A4%EC%9D%84-%EB%AA%A8%EC%8B%AD%EB%8B%88%EB%8B%A4-%EA%B8%B0%ED%9A%8DPM'),
#    ('모빌리티의 미래를 그릴 분들을 모십니다. (디자인, 신입~3년 이하)',
#     '/jobs/146300/%EB%AA%A8%EB%B9%8C%EB%A6%AC%ED%8B%B0%EC%9D%98-%EB%AF%B8%EB%9E%98%EB%A5%BC-%EA%B7%B8%EB%A6%B4-%EB%B6%84%EB%93%A4%EC%9D%84-%EB%AA%A8%EC%8B%AD%EB%8B%88%EB%8B%A4-%EB%94%94%EC%9E%90%EC%9D%B8-%EC%8B%A0%EC%9E%853%EB%85%84-%EC%9D%B4%ED%95%98')]},
#  {'회사명': '지엔에이컴퍼니',
#   '설명': '게이머들을 위한 멤버십 서비스 [플레이오]를 만들고 있습니다.',
#   '공고들': [('Customer Experience Manager',
#     '/jobs/134488/Customer-Experience-Manager'),
#    ('[플레이오] 게임사 담당 어카운트 매니저',
#     '/jobs/103855/%ED%94%8C%EB%A0%88%EC%9D%B4%EC%98%A4-%EA%B2%8C%EC%9E%84%EC%82%AC-%EB%8B%B4%EB%8B%B9-%EC%96%B4%EC%B9%B4%EC%9A%B4%ED%8A%B8-%EB%A7%A4%EB%8B%88%EC%A0%80'),
#    ('[플레이오] CX Manager / Customer Satisfaction',
#     '/jobs/118834/%ED%94%8C%EB%A0%88%EC%9D%B4%EC%98%A4-CX-Manager-Customer-Satisfaction'),
#    ('[플레이오] 프로덕트 데이터 분석가',
#     '/jobs/146129/%ED%94%8C%EB%A0%88%EC%9D%B4%EC%98%A4-%ED%94%84%EB%A1%9C%EB%8D%95%ED%8A%B8-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EB%B6%84%EC%84%9D%EA%B0%80'),
#    ('Playio Sales Manager', '/jobs/145834/Playio-Sales-Manager'),
#    ('[Playio] 사업 개발 Business Development',
#     '/jobs/103854/Playio-%EC%82%AC%EC%97%85-%EA%B0%9C%EB%B0%9C-Business-Development'),
#    ('[플레이오] Python 백엔드 개발자',
#     '/jobs/144042/%ED%94%8C%EB%A0%88%EC%9D%B4%EC%98%A4-Python-%EB%B0%B1%EC%97%94%EB%93%9C-%EA%B0%9C%EB%B0%9C%EC%9E%90')]},
#  {'회사명': '주식회사 리하베스트',
#   '설명': 'Re-think valuable food resources for the planet we love.',
#   '공고들': [('Brand MD / 상품기획',
#     '/jobs/146405/Brand-MD-%EC%83%81%ED%92%88%EA%B8%B0%ED%9A%8D')]}]

# %% [markdown]
# ---
# 삼성전자 주식 시세 크롤링
# - 일별 시세 탭에 있는 데이터를 모두 크롤링해주세요.
# - 성공하신분들은 총 10페이지까지 크롤링해주세요.
# - https://finance.naver.com/item/sise.naver?code=005930

# %%
# 참고
r = requests.get('https://api.finance.naver.com/service/itemSummary.naver?itemcode=005930&_callback=window.__jindo2_callback._6342')

idx = r.text.index('{')
json.loads(r.text[idx:-1])
# Out:
# {'marketSum': 438182039,
#  'per': 11.08,
#  'eps': 6625.0,
#  'pbr': 1.42,
#  'now': 73400,
#  'diff': 1500,
#  'rate': 2.09,
#  'quant': 15738175,
#  'amount': 1149402,
#  'high': 73400,
#  'low': 72400,
#  'risefall': 2}

# %%
# 참고
import re
re.search('{.+}', r.text).group()
# Out:
# '{"marketSum":438182039,"per":11.08,"eps":6625.0,"pbr":1.42,"now":73400,"diff":1500,"rate":2.09,"quant":15738175,"amount":1149402,"high":73400,"low":72400,"risefall":2}'

# %%
headers = {'User-Agent' :'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}

# %%
url = 'https://finance.naver.com/item/sise_day.naver?code=005930&page={}'

response = requests.get(url.format(2), headers=headers)
response
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(response.text, 'html.parser')

# %%
stocks= []
for tr_tag in soup.select('tr'):
    if tr_tag.select_one('.num'):  # .num 이 있을 경우
        stocks.append([td.text.strip() for td in tr_tag.select('td')])
    
    else:
        ...

# %%
stocks
# Out:
# [['2023.06.30', '72,200', '200', '72,500', '72,700', '71,700', '11,694,765'],
#  ['2023.06.29', '72,400', '300', '73,100', '73,400', '72,400', '12,229,967'],
#  ['2023.06.28', '72,700', '100', '72,600', '72,700', '72,000', '8,783,093'],
#  ['2023.06.27', '72,600', '200', '72,500', '72,600', '72,000', '9,442,997'],
#  ['2023.06.26', '72,400', '800', '71,700', '72,500', '71,500', '10,541,901'],
#  ['2023.06.23', '71,600', '300', '72,000', '72,200', '71,600', '12,329,484'],
#  ['2023.06.22', '71,300', '800', '70,200', '71,500', '70,100', '11,411,007'],
#  ['2023.06.21', '70,500', '900', '70,700', '71,200', '70,400', '10,626,603'],
#  ['2023.06.20', '71,400', '200', '70,700', '71,400', '70,400', '11,557,883'],
#  ['2023.06.19', '71,200', '600', '71,300', '71,700', '70,900', '11,100,887']]

# %%
for page in range(1, 11):
    response = requests.get('https://finance.naver.com/item/sise_day.naver?code=005930&page={}'.format(page), headers=headers)

    soup= BeautifulSoup(response.text, 'html.parser')
    stocks= []
    for tr_tag in soup.select('tr'):
        if tr_tag.select_one('.num'):  # .num 이 있을 경우
            stocks.append([td.text.strip() for td in tr_tag.select('td')])
        
        else:
            ...

# %%
stocks
# Out:
# [['2023.03.06', '61,500', '1,000', '61,100', '61,600', '60,800', '13,630,602'],
#  ['2023.03.03', '60,500', '300', '61,000', '61,200', '60,500', '10,711,405'],
#  ['2023.03.02', '60,800', '200', '60,900', '61,800', '60,500', '13,095,682'],
#  ['2023.02.28', '60,600', '100', '60,800', '61,400', '60,500', '13,715,861'],
#  ['2023.02.27', '60,500', '800', '60,800', '60,800', '60,200', '11,155,697'],
#  ['2023.02.24', '61,300', '700', '62,300', '62,600', '61,300', '10,308,143'],
#  ['2023.02.23', '62,000', '900', '61,700', '62,500', '61,500', '13,047,099'],
#  ['2023.02.22', '61,100', '1,000', '61,500', '61,800', '61,000', '11,959,088'],
#  ['2023.02.21', '62,100', '600', '62,700', '62,800', '62,000', '7,665,046'],
#  ['2023.02.20', '62,700', '100', '62,900', '63,000', '61,800', '12,908,073']]
